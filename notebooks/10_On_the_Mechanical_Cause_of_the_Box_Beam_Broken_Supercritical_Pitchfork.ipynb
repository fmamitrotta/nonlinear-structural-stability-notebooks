# %% [raw]
# Code provided under BSD 3-Clause license, all other content under a Creative Commons Attribution license, CC-BY 4.0. (c) 2022 Francesco Mario Antonio Mitrotta.

# %% [markdown]
# # On the Mechanical Cause of the Box Beam's Broken Supercritical Pitchfork
#
# ***
#
# In this notebook we demonstrate the mechanical cause of the broken supercritical pitchfork response observed for both the [unreinforced](06_Nonlinear_Buckling_Method_Verification.ipynb) and the [reinforced box beam](08_Nonlinear_Buckling_Analysis_of_a_Box_Beam_Reinforced_with_Ribs.ipynb#nonlinear-buckling-method-verification) under a concentrated bending load applied at the tip.
#
# * [Introduction](#introduction)
# * [Unreinforced box beam](#unreinforced)
#     * [Setup of the numerical model](#unreinforced-numerical-model)
#     * [Linear buckling analysis](#unreinforced-linear-buckling)
#     * [Nonlinear analysis](#unreinforced-nonlinear-analysis)
#     * [Stress results](#unreinforced-stress-results)
# * [Reinforced box beam](#reinforced)
#     * [Setup of the numerical model](#reinforced-numerical-model)
#     * [Linear buckling analysis](#reinforced-linear-buckling)
#     * [Nonlinear analysis](#reinforced-nonlinear-analysis)
#     * [Stress results](#reinforced-stress-results)
# * [Conclusion](#conclusion)

# %%
FIRST_SUBCASE_ID = 1

# %% [markdown]
# ## Introduction <a name="introduction"></a>
#
# ***
#
# In our previous notebooks we observed that a box beam loaded in pure bending experiences a nonlinear response analogous to the natural path of a broken supercritical pitchfork, where the structure is always stable. In this notebook we make the hypothesis that this response is caused by an asymmetry of the internal loads about the midplane of the top skin, which is a consequence of the global top-down asymmetry introduced by the bending load.
#
# We can observe this asymmetry in the figure below, where a cross-sectional view of an unreinforced box beam is shown. The concentrated tip load $P$ causes a deflection of the box beam that brings the top skin under compression and the bottom skin under tension. If we look at the axial stresses in the spars at the section cut by the axis $z_{local}$, these must vary from positive to negative along the local height. Also the axial stresses in each skin must have an analogous variation between the local top and bottom plane. However, in this case the variation is between two positive values for the bottom skin and between two negative values for the top skin. As a consequence, there is no symmetry of the stresses, and thus of the internal loads, about the midplane of the top skin, which causes the theoretical supercritical pitchfork bifurcation to break down. This in turn gives rise to broken supercritical pitchfork response observed in our previous notebooks.

# %%
from IPython.display import SVG  # class to embed an SVG into the display
import os  # module with miscellaneous operating system interfaces

SVG(filename=os.path.join('resources', '10_BoxBeamStresses.svg'))

# %% [markdown]
# We are going to test this hypothesis on both the unreinforced and the reinforced box beam configuration.

# %% [markdown]
# ## Unreinforced box beam <a name="unreinforced"></a>
#
# ***
#
# ### Setup of the numerical model <a name="unreinforced-numerical-model"></a>
#
# We consider an unreinforced box beam with the same geometry and material properties as in our previous notebooks.

# %%
SVG(filename=os.path.join('resources', '04_BoxBeamGeometry.svg'))

# %%
AR = 9.   # aspect ratio - 2*b/w (the length of the box beam corresponds to half the span of the CRM wing)
w = 1e3   # width [mm]
l = AR*w/2  # length [mm]
non_dimensional_height = 0.2  # h/w
h = w*non_dimensional_height  # box height [mm]
non_dimensional_thickness = 1/50  # t/h
t = h*non_dimensional_thickness   # shell thickness [mm]
print(f"""Box beam dimensions:
- width: {w/1e3:.2f} m
- length: {l/1e3:.2f} m
- height: {h/1e3:.2f} m
- wall thickness: {t:.2f} mm""")
# Out:
# Box beam dimensions:
# - width: 1.00 m
# - length: 4.50 m
# - height: 0.20 m
# - wall thickness: 4.00 mm

# %%
rho = 2780e-12  # density [ton/mm^3]
E = 73.1e3  # Young's modulus [MPa]
nu = 0.3  # Poisson's ratio

# %% [markdown]
# We create a mesh of quadrilateral elements using the function `mesh_box_with_pyvista` from the `box_beam_utils` module. We prescribe an element length of 60 mm based on the results of a previous [mesh convergence study](04_Nonlinear_Buckling_Analysis_of_a_Box_Beam.ipynb#mesh-convergence).

# %%
from resources import box_beam_utils

shell_element_length = 59.9  # [mm]
unreinforced_box_beam_mesh = box_beam_utils.mesh_box_beam(width=w, length=l, height=h, element_length=shell_element_length)
nodes_coordinates_array = unreinforced_box_beam_mesh.points
nodes_connectivity_matrix = unreinforced_box_beam_mesh.faces.reshape(-1, 5)[:, 1:]

# %% [markdown]
# Now we create a base `BDF` object calling the function `create_base_bdf_input` where we define fixed boundary conditions at the root of the box beam.

# %%
unreinforced_box_beam_bdf = box_beam_utils.create_base_bdf_input(
    young_modulus=E, poisson_ratio=nu, density=rho, shell_thickness=t, nodes_xyz_array=nodes_coordinates_array,
    nodes_connectivity_matrix=nodes_connectivity_matrix)
print(unreinforced_box_beam_bdf.get_bdf_stats())  # print cards of BDF object
# Out:
# ---BDF Statistics---
# SOL None
#
# bdf.spcs[1]: 1
#   SPC1:    1
#
# bdf.params: 0
#   PARAM    : 1
#
# bdf.nodes: 0
#   GRID     : 3388
#
# bdf.elements: 0
#   CQUAD4   : 3344
#
# bdf.properties: 0
#   PSHELL   : 1
#
# bdf.materials: 0
#   MAT1     : 1
# subcase=0 already exists...skipping

# %% [markdown]
# Then we apply a concentrated tip load at the center of the tip section as shown below. We use a `RBE2` element to connect the nodes along the tip section to the node in the center.

# %%
SVG(filename=os.path.join('resources', '04_BoxBeamConcentratedLoad.svg'))

# %%
import numpy as np
from resources import pynastran_utils

# Find id of tip nodes
nodes_ids = np.arange(1, np.size(nodes_coordinates_array, 0) + 1)
tolerance = shell_element_length/100
tip_nodes_ids = nodes_ids[np.abs(nodes_coordinates_array[:,1] - l) < tolerance]

# Add master node of tip section
tip_master_node_id = np.amax(nodes_ids) + 1
unreinforced_box_beam_bdf.add_grid(tip_master_node_id, [w/2, l, 0.])

# Add RBE2 to connect master node with outer nodes of tip rib
rbe2_eid = len(unreinforced_box_beam_bdf.elements) + 1
unreinforced_box_beam_bdf.add_rbe2(eid=rbe2_eid, gn=tip_master_node_id, cm='123456', Gmi=tip_nodes_ids)

# Add concentrated force
force_set_id = 11
force_direction = [0., 0., 1.]
pynastran_utils.add_uniform_force(
    bdf=unreinforced_box_beam_bdf, nodes_ids=[tip_master_node_id], set_id=force_set_id, direction_vector=force_direction)

# %% [markdown]
# ### Linear buckling analysis <a name="unreinforced-linear-buckling"></a>
#
# We use SOL 105 to calculate the linear buckling load and the corresponding buckling shape, so that we have a reference for the nonlinear analysis.

# %%
import matplotlib.pyplot as plt
from resources import plot_utils  # module with functions to plot results of Nastran analyses

# Run SOL 105 and return OP2 object
analysis_directory_name = '10_On_the_Mechanical_Cause_of_the_Box_Beam_Broken_Supercritical_Pitchfork'
analysis_directory_path = os.path.join(os.getcwd(), 'analyses', analysis_directory_name)
input_name = 'unreinforced_box_beam_linear_buckling'
sol_105_op2 = pynastran_utils.run_sol_105(
    bdf=unreinforced_box_beam_bdf.__deepcopy__({}),  # we pass a deep copy of the BDF object to be able to set up the nonlinear analysis later
    static_load_set_id=force_set_id, analysis_directory_path=analysis_directory_path, input_name=input_name, run_flag=False)

# Define function to adjust axes ticks and labels' position
def adjust_3d_plot(axes, colorbar=None):
    axes.locator_params(axis='x', nbins=3)  # set number of ticks of x-axis
    axes.locator_params(axis='z', nbins=2)  # set number of ticks of z-axis
    axes.tick_params(axis='y', which='major', pad=20)  # adjust position of ticks' label of y-axis
    axes.tick_params(axis='z', which='major', pad=6)  # adjust position of ticks' label of z-axis
    axes.yaxis.labelpad = 60  # adjust position of y-axis's label
    axes.zaxis.labelpad = 10  # adjust position of z-axis's label
    if colorbar is not None:
        colorbar.ax.set_position(colorbar.ax.get_position().shrunk(1.0, .66))  # decrease colorbar size
        colorbar.ax.set_position(colorbar.ax.get_position().translated(0, .14))  # move colorbar upwards

# Print critical buckling load and plot mode
sol_105_buckling_load = sol_105_op2.eigenvectors[2].eigr
print(f"Buckling load: {sol_105_buckling_load:.0f} N")
plt.rcParams['figure.dpi'] = 120  # set default dpi of figures
print(f"Buckling mode:")
AMPLIFICATION_FACTOR = 100
_, ax, cbar = plot_utils.plot_eigenvector(
    op2=sol_105_op2, subcase_id=2, displacement_component='tz', colormap='sunset',
    displacement_amplification_factor=AMPLIFICATION_FACTOR, length_unit="mm")
adjust_3d_plot(ax, cbar)
plt.show()
# Out:
# Buckling load: 1654 N
# Buckling mode:

# %% [markdown]
# ### Nonlinear analysis <a name="unreinforced-nonlinear-analysis"></a>
#
# Now we set up our nonlinear analysis (SOL 106) with the arc-length method using the function `set_up_arc_length_method` from the `pynastran_utils` module. We use the set of parameters obtained from a [previous sensitivity study](08_Nonlinear_Buckling_Analysis_of_a_Box_Beam_Reinforced_with_Ribs.ipynb#nonlinear-analysis-parameters) on the nonlinear analysis parameters.

# %%
pynastran_utils.set_up_arc_length_method(bdf=unreinforced_box_beam_bdf, conv='PU', eps_p=1e-2, eps_u=1e-2,
                                         ninc=100, desiter=5, maxalr=1.01, maxinc=200)  # set up nonlinear analysis with arc-length method

# %% [markdown]
# Let's define the magnitude of the applied load as twice the buckling load obtained by SOL 105 and let's create the corresponding subcase. We also add a case control command to store the nonlinear stress results in the op2 file.

# %%
# Define applied load magnitude
load_set_id = force_set_id + 1
load_magnitude = sol_105_buckling_load*2
unreinforced_box_beam_bdf.add_load(sid=load_set_id, scale=1., scale_factors=[load_magnitude], load_ids=[force_set_id])

# Create subcase
subcase_id = 1
pynastran_utils.create_static_load_subcase(bdf=unreinforced_box_beam_bdf, subcase_id=subcase_id,
                                           load_set_id=load_set_id)

# Store nonlinear stress results of all elements in the op2 file
unreinforced_box_beam_bdf.case_control_deck.subcases[0].add_result_type('NLSTRESS', 'ALL', ['PLOT'])

# %% [markdown]
# We run the analysis and plot the load-displcacement diagram in terms of the tip displacement $u_{z, tip}$ nondimensionalized by the lenght of the box beam $l$. We also plot the final deformation shape.

# %%
from pyNastran.op2.op2 import read_op2  # import function to read op2 file

# Run analysis
input_name = 'unreinforced_box_beam_nonlinear_analysis'
pynastran_utils.run_analysis(directory_path=analysis_directory_path, bdf=unreinforced_box_beam_bdf,
                             filename=input_name, run_flag=False)

# Read op2 file
op2_filepath = os.path.join(analysis_directory_path, input_name + '.op2')
sol_106_op2 = read_op2(op2_filename=op2_filepath, load_geometry=True, debug=None)

# Find load and displacement history
_, loads, displacements = pynastran_utils.read_load_displacement_history_from_op2(
    op2=sol_106_op2, node_ids=[tip_master_node_id])

# Select translation along z as the load and displacement components to plot
load_component_index = 2
displacement_component_index = 2

# Plot load-displacement diagram
_, ax = plt.subplots()
ax.plot(displacements[tip_master_node_id][FIRST_SUBCASE_ID][:,displacement_component_index]/l,
        loads[FIRST_SUBCASE_ID][:, load_component_index]/sol_105_buckling_load, 'o')
plt.xlabel("$u_{z, tip}/l$")
plt.ylabel("$P/P_\mathrm{SOL 105}$")
plt.grid()
plt.show()

# Plot final static deformation
_, ax, cbar = plot_utils.plot_deformation(
    op2=sol_106_op2, subcase_id=subcase_id, displacement_component='tz', length_unit="mm")
adjust_3d_plot(ax, cbar)
plt.show()
# Out:
# Nastran job unreinforced_box_beam_nonlinear_analysis.bdf completed
# Wall time: 123.0 s

# %% [markdown]
# As expected we find a change in the slope of the load-dislacement diagram at $P/P_\text{SOL 105}=1$ and a buckled-like shape for the top skin.

# %% [markdown]
# ### Stress results <a name="unreinforced-stress-results"></a>
#
# Now we want to look at the axial stresses in the top skin at a given $y$ location to verify that there is no symmetry about the midplane. We consider the first load increment of the nonlinear analysis, approximately $P/P_\text{SOL 105}=0.02$. In fact, if the symmetry of the internal loads breaks down, it should do so from the start of the loading process. Since Nastran's stress output is given in terms of the element's local $x$ and $y$ axes, we first need to understand the orientation of the elements' coordinate system with respect to the global one. For this reason we plot all the elements of the top skin and the coordinate system of the first element, where the $x$ axis is colored in red, the $y$ axis is colored in green and the $z$ axis is colored in blue. We only need to look at the coordinate system of one of the elements because the mesh creation process enforces all elements of the same structural part (top skin in this case) to have the same coordinate system, which in turn is defined by Nastran's convention for `CQUAD4` elements.

# %%
import tol_colors as tc  # package for colorblind-friendly colors
from mpl_toolkits.mplot3d.art3d import Poly3DCollection  # class for 3d polygons

# Set default color cycle to TOL bright for colorblind-friendly colors and get list of those colors
plt.rc('axes', prop_cycle=plt.cycler('color', list(tc.tol_cset('bright'))))
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# Find coordinates of nodes and centroid of all elements
elements_nodes_xyz = np.stack([e.get_node_positions() for e in sol_106_op2.elements.values()], axis=0)  # array with shape no_elements x 4 (number of nodes per element) x 3 (x, y, z coordinates of each node)
elements_centroid_xyz = np.sum(elements_nodes_xyz, axis=1)/4  # array with shape no_elements x 3 (x, y, z coordinates of the element's centroid)

# Find nodes coordinates of top skin elements
top_skin_indices = np.where(np.abs(elements_centroid_xyz[:,2] - h/2) < tolerance)[0]  # find indices of the elements with centroid at z=h/2
top_skin_elements_nodes_xyz = elements_nodes_xyz[top_skin_indices, :, :]

# Find the coordinate system of the first element of the top skin
elements_ids = np.asarray(list(sol_106_op2.elements.keys()))
element_coordinate_system = sol_106_op2.elements[elements_ids[top_skin_indices[0]]].element_coordinate_system()

# Create figure with 3d axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot elements
pc = Poly3DCollection(top_skin_elements_nodes_xyz, linewidths=.5, alpha=.3)
pc.set_edgecolor('k')
ax.add_collection3d(pc)

# Plot element coordinate system
arrow_length = 500
arrowhead_length_ratio = .4
ax.quiver(element_coordinate_system[1][0], element_coordinate_system[1][1], element_coordinate_system[1][2],
               element_coordinate_system[2][0], element_coordinate_system[2][1], element_coordinate_system[2][2],
               color=colors[1], length=arrow_length, arrow_length_ratio=arrowhead_length_ratio)  # x-axis (red)
ax.quiver(element_coordinate_system[1][0], element_coordinate_system[1][1], element_coordinate_system[1][2],
               element_coordinate_system[3][0], element_coordinate_system[3][1], element_coordinate_system[3][2],
               color=colors[2], length=arrow_length, arrow_length_ratio=arrowhead_length_ratio)  # y-axis (green)
ax.quiver(element_coordinate_system[1][0], element_coordinate_system[1][1], element_coordinate_system[1][2],
               element_coordinate_system[4][0], element_coordinate_system[4][1], element_coordinate_system[4][2],
               color=colors[0], length=arrow_length, arrow_length_ratio=arrowhead_length_ratio)  # z-axis (blue)

# Set plot appearance and show
ax.set_xlabel("$x$, mm")
ax.set_ylabel("$y$, mm")
ax.set_zlabel("$z$, mm")
bounds = np.array([
    [np.amin(elements_nodes_xyz[:, :, 0]), np.amax(elements_nodes_xyz[:, :, 0])],
    [np.amin(elements_nodes_xyz[:, :, 1]), np.amax(elements_nodes_xyz[:, :, 1])],
    [np.amin(elements_nodes_xyz[:, :, 2]), np.amax(elements_nodes_xyz[:, :, 2])]])  # array with shape 3 x 2 (min and max values of x, y, z coordinates)
ax.set_box_aspect([x[1]-x[0] for x in list(bounds)])  # set aspect ratio
ax.set_xlim(bounds[0, :])
ax.set_ylim(bounds[1, :])
ax.set_zlim(bounds[2, :])
adjust_3d_plot(ax)
plt.show()

# %% [markdown]
# We can observe that the elements' local $y$ axis is aligned with the global $y$ axis, while the local $x$ and $z$ axes point towards the opposite direction with respect to the global axes. Since we are interested in the axial stress, we are going to look at the stress along the $y$ axis of the elements.
#
# We select $y=400$ mm as the location where we want to inspect the axial stresses in the top skin because it approximately corresponds to the displacement peak of the first "blob" in the deformation of the box beam at $P/P_\text{SOL 105}=2$. We then plot the axial stress $\sigma_y$ over the top and bottom plane of the top skin along the $y=400$ mm section.

# %%
# Find id of the elements located along the prescribed section
stress_profile_y_location = 400  # [mm]
stress_profile_element_indices = np.where(
    (elements_centroid_xyz[:, 1] == elements_centroid_xyz[np.argmin(np.abs(
        elements_centroid_xyz[:, 1] - stress_profile_y_location)), 1]) &  # select elements with y-coordinate of centroid closest to the y-coordinate of the prescribed section
        (np.abs(elements_centroid_xyz[:, 2] - h/2) < tolerance)  # select elements of top skin
        )[0]  # find indices of top skin elements located along the prescribed section
stress_profile_element_ids = elements_ids[stress_profile_element_indices]  # find corresponding elements ids

# Find stress data of top skin elements along the prescribed section
stress_profile_data = np.stack([sol_106_op2.nonlinear_cquad4_stress[subcase_id].data[
    0,  # first converged load step
    np.where(sol_106_op2.nonlinear_cquad4_stress[subcase_id].element == eid)[0][0]*2:
    np.where(sol_106_op2.nonlinear_cquad4_stress[subcase_id].element == eid)[0][0]*2 + 2,  # row indices of bottom and top plane of the current element id
    2]  # take stress along local y-axis of the element for both the bottom and top plane
    for eid in stress_profile_element_ids],  # iterate through the element ids
    axis=0)  # stack data so that final array has shape no_stress_profile_elements x 2 (bottom and top plane)

# Find x location of the elements' centroid along the prescribed section
elements_centroid_x = elements_centroid_xyz[stress_profile_element_indices, 0]

# Plot axial stress vs x coordinate of the element for both the top and bottom plane
_, ax = plt.subplots()
ax.plot(elements_centroid_x, stress_profile_data[:, 0], 'o-', label="Top plane")
ax.plot(elements_centroid_x, stress_profile_data[:, 1], 'v-', label="Bottom plane")
ax.legend()
plt.xlabel("$x$, mm")
plt.ylabel("$\sigma_y$, MPa")
plt.grid()
plt.show()

# %% [markdown]
# We observe that the stress at the top plane is more negative than the one at the bottom plane, as expected, implying an asymmetry about the midplane of the top skin.

# %% [markdown]
# ## Reinforced box beam <a name="reinforced"></a>
#
# ***
#
# ### Setup of the numerical model <a name="reinforced-numerical-model"></a>
#
# We consider the same geometry and material used for the unreinforced box beam and prescribe the same ribs spacing employed in a [previous notebook](08_Nonlinear_Buckling_Analysis_of_a_Box_Beam_Reinforced_with_Ribs.ipynb).

# %%
SVG(filename=os.path.join('resources', '08_BoxBeamGeometry.svg'))

# %%
ribs_spacing = w/2  # half of box beam's width
no_ribs = int(np.ceil(l/ribs_spacing)) + 1  # calculate number of ribs
ribs_y_locations = np.linspace(0, l, no_ribs)  # calculate y-coordinates of the ribs

# Print information to screen
np.set_printoptions(precision=0)
print(f"Number of ribs: {no_ribs:.0f}")
print("Ribs' y-coordinate [mm]:")
print(ribs_y_locations)
# Out:
# Number of ribs: 10
# Ribs' y-coordinate [mm]:
# [   0.  500. 1000. 1500. 2000. 2500. 3000. 3500. 4000. 4500.]

# %% [markdown]
# We create a mesh of quadrilateral elements using the function `mesh_box_beam_with_pyvista` from the `box_beam_utils` module. We prescribe an element length of 60 mm based on the results of a previous [mesh convergence study](08_Nonlinear_Buckling_Analysis_of_a_Box_Beam_Reinforced_with_Ribs.ipynb#mesh-convergence).

# %%
reinforced_box_beam_mesh = box_beam_utils.mesh_box_beam_reinforced_with_ribs(
    ribs_y_coordinates=ribs_y_locations, width=w, height=h, element_length=shell_element_length)
nodes_coordinates_array = reinforced_box_beam_mesh.points
nodes_connectivity_matrix = reinforced_box_beam_mesh.faces.reshape(-1, 5)[:, 1:]

# %% [markdown]
# We create a base `BDF` object with fixed boundary conditions at the box beam root.

# %%
reinforced_box_beam_bdf = box_beam_utils.create_base_bdf_input(
    young_modulus=E, poisson_ratio=nu, density=rho, shell_thickness=t, nodes_xyz_array=nodes_coordinates_array,
    nodes_connectivity_matrix=nodes_connectivity_matrix)
print(reinforced_box_beam_bdf.get_bdf_stats())  # print cards of BDF object
# Out:
# ---BDF Statistics---
# SOL None
#
# bdf.spcs[1]: 1
#   SPC1:    1
#
# bdf.params: 0
#   PARAM    : 1
#
# bdf.nodes: 0
#   GRID     : 4514
#
# bdf.elements: 0
#   CQUAD4   : 4680
#
# bdf.properties: 0
#   PSHELL   : 1
#
# bdf.materials: 0
#   MAT1     : 1
# subcase=0 already exists...skipping

# %% [markdown]
# Then we apply a concentrated tip load in an analogous way as done for the unreinforced box beam. This time we use a RBE3 element to connect the nodes along the outer edges of the tip section to the node in the center as the rigidity of the tip is enforced by the presence of a physical rib.

# %%
# Find outer nodes of tip rib
nodes_ids = np.arange(1, np.size(nodes_coordinates_array, 0) + 1)
outer_tip_nodes_ids = nodes_ids[(np.abs(nodes_coordinates_array[:, 1] - l) < tolerance) &  # nodes at the tip
                                ((nodes_coordinates_array[:, 0] < tolerance) |  # nodes along the front spar
                                 (np.abs(nodes_coordinates_array[:, 0] - w) < tolerance) |  # nodes along the rear spar
                                 (np.abs(nodes_coordinates_array[:, 2] - h/2) < tolerance) |  # nodes on the top skin
                                 (np.abs(nodes_coordinates_array[:, 2] + h/2) < tolerance))]  # nodes on the bottom skin

# Add master node of tip section
tip_master_node_id = np.amax(nodes_ids) + 1
reinforced_box_beam_bdf.add_grid(tip_master_node_id, [w/2, l, 0.])

# Add RBE3 to connect master node with outer nodes of tip rib
rbe3_eid = len(reinforced_box_beam_bdf.elements) + 1
reinforced_box_beam_bdf.add_rbe3(eid=rbe3_eid, refgrid=tip_master_node_id, refc='123456',
                                 weights=[1.]*len(outer_tip_nodes_ids), comps=['123456']*len(outer_tip_nodes_ids),
                                 Gijs=outer_tip_nodes_ids)

# Add concentrated force
pynastran_utils.add_uniform_force(
    bdf=reinforced_box_beam_bdf, nodes_ids=[tip_master_node_id], set_id=force_set_id, direction_vector=force_direction)

# %% [markdown]
# ### Linear buckling analysis <a name="reinforced-linear-buckling"></a>
#
# Once again, we use SOL 105 to calculate the linear buckling load and the corresponding buckling shape.

# %%
# Run SOL 105 and return OP2 object
input_name = 'reinforced_box_beam_linear_buckling'
sol_105_op2 = pynastran_utils.run_sol_105(
    bdf=reinforced_box_beam_bdf.__deepcopy__({}),  # we pass a deep copy of the BDF object to be able to set up the nonlinear analysis later
    static_load_set_id=force_set_id, analysis_directory_path=analysis_directory_path, input_name=input_name, run_flag=False)

# Print critical buckling load and plot mode
sol_105_buckling_load = sol_105_op2.eigenvectors[2].eigr
print(f'Buckling load: {sol_105_buckling_load:.0f} N')
plt.rcParams['figure.dpi'] = 120  # set default dpi of figures
print(f'Buckling mode:')
_, ax, cbar = plot_utils.plot_eigenvector(
    op2=sol_105_op2, subcase_id=2, displacement_component='tz', colormap='sunset',
    displacement_amplification_factor=AMPLIFICATION_FACTOR, length_unit="mm")
adjust_3d_plot(ax, cbar)
plt.show()
# Out:
# Buckling load: 3101 N
# Buckling mode:

# %% [markdown]
# ### Nonlinear analysis <a name="reinforced-nonlinear-analysis"></a>
#
# We initialize the nonlinear analysis with the arc-length method setting the same parameters used previously and we create a subcase with an applied load equal to twice the linear buckling load.

# %%
pynastran_utils.set_up_arc_length_method(bdf=reinforced_box_beam_bdf, conv='PU', eps_p=1e-2, eps_u=1e-2, ninc=100,
                                         desiter=5, maxalr=1.01, maxinc=200)  # set up nonlinear analysis with arc-length method
reinforced_box_beam_bdf.case_control_deck.subcases[0].add_result_type('NLSTRESS', 'ALL', ['PLOT'])  # store nonlinear stress results of all elements in the op2 file
load_magnitude = sol_105_buckling_load*2  # define applied load magnitude
reinforced_box_beam_bdf.add_load(sid=load_set_id, scale=1., scale_factors=[load_magnitude], load_ids=[force_set_id])  # add LOAD card
pynastran_utils.create_static_load_subcase(bdf=reinforced_box_beam_bdf, subcase_id=subcase_id,
                                           load_set_id=load_set_id)  # create subcase

# %% [markdown]
# Let's run the analysis and plot the load-displacement diagram and the final deformation shape.

# %%
# Run analysis
input_name = 'reinforced_box_beam_nonlinear_analysis'
pynastran_utils.run_analysis(directory_path=analysis_directory_path, bdf=reinforced_box_beam_bdf,
                             filename=input_name, run_flag=False)

# Read op2 file
op2_filepath = os.path.join(analysis_directory_path, input_name + '.op2')
sol_106_op2 = read_op2(op2_filename=op2_filepath, load_geometry=True, debug=None)

# Find load and displacement history
_, loads, displacements = pynastran_utils.read_load_displacement_history_from_op2(
    op2=sol_106_op2, node_ids=[tip_master_node_id])

# Select translation along z as the load and displacement components to plot
load_component_index = 2
displacement_component_index = 2

# Plot load-displacement diagram
_, ax = plt.subplots()
ax.plot(displacements[tip_master_node_id][FIRST_SUBCASE_ID][:,displacement_component_index]/l,
        loads[FIRST_SUBCASE_ID][:, load_component_index]/sol_105_buckling_load, 'o')
plt.xlabel("$u_{z, tip}/l$")
plt.ylabel("$P/P_\mathrm{SOL 105}$")
plt.grid()
plt.show()

# Plot final static deformation
_, ax, cbar = plot_utils.plot_deformation(
    op2=sol_106_op2, subcase_id=subcase_id, displacement_component='tz', length_unit="mm")
adjust_3d_plot(ax, cbar)
plt.show()
# Out:
# Nastran job reinforced_box_beam_nonlinear_analysis.bdf completed
# Wall time: 176.0 s

# %% [markdown]
# Also in this case we observe a change in the slope of the load-displacement diagram approximately at $P/P_\text{SOL 105}=1$ and a buckled-like shape of the top skin.

# %% [markdown]
# ### Stress results <a name="reinforced-stress-results"></a>
#
# Analogously to the unreinforced box beam case, we plot the axial stress $\sigma_y$ along the prescribed section for both the top and bottom plane. We consider again the section at $y=400$ mm.

# %%
# Find id of top skin elements located along the prescribed section
elements_ids = np.asarray(list(sol_106_op2.elements.keys()))  # array of elements ids
elements_nodes_xyz = np.stack([e.get_node_positions() for e in sol_106_op2.elements.values()], axis=0)  # array with shape no_elements x 4 (number of nodes per element) x 3 (x, y, z coordinates of each node)
elements_centroid_xyz = np.sum(elements_nodes_xyz, axis=1)/4  # array with shape no_elements x 3 (x, y, z coordinates of the element's centroid)
stress_profile_element_indices = np.where(
    (elements_centroid_xyz[:, 1] == elements_centroid_xyz[np.argmin(np.abs(
        elements_centroid_xyz[:, 1] - stress_profile_y_location)), 1]) &  # select elements with y-coordinate of centroid closest to the y-coordinate of the prescribed section
        (np.abs(elements_centroid_xyz[:, 2] - h/2) < tolerance)  # select elements of top skin
        )[0]  # find indices of top skin elements located along the prescribed section
stress_profile_element_ids = elements_ids[stress_profile_element_indices]  # find corresponding elements ids

# Find stress data of top skin elements along the prescribed section
stress_profile_data = np.stack([sol_106_op2.nonlinear_cquad4_stress[subcase_id].data[
    0,  # first converged load step
    np.where(sol_106_op2.nonlinear_cquad4_stress[subcase_id].element == eid)[0][0]*2:
    np.where(sol_106_op2.nonlinear_cquad4_stress[subcase_id].element == eid)[0][0]*2 + 2,  # row indices of bottom and top plane of the current element id
    2]  # take stress along local y-axis of the element for both the bottom and top plane
    for eid in stress_profile_element_ids],  # iterate through the element ids
    axis=0)  # stack data so that final array has shape no_stress_profile_elements x 2 (bottom and top plane)

# Find x location of the elements' centroid along the prescribed section
elements_centroid_x = elements_centroid_xyz[stress_profile_element_indices, 0]

# Plot axial stress vs x coordinate of the element for both the top and bottom plane
_, ax = plt.subplots()
ax.plot(elements_centroid_x, stress_profile_data[:, 0], 'o-', label="Top plane")
ax.plot(elements_centroid_x, stress_profile_data[:, 1], 'v-', label="Bottom plane")
ax.legend()
plt.xlabel("$x$, mm")
plt.ylabel("$\sigma_y$, MPa")
plt.grid()
plt.show()

# %% [markdown]
# Also in this case the axial stress varies from a more negative value at the top plane to a less negative value at the bottom plane, as expected. Once again this implies an asymmetry of the internal load of the top skin about its midplane.
#
# ## Conclusion <a name="conclusion"></a>
#
# ***
#
# In this notebook we have demonstrated that the bending load introduces an asymmetry in the internal load of the top skin of the box beam. This has been observed for both the unreinforced and the reinforced configuration. The results corroborate the hypothesis that the broken supercritical pitchfork response observed in the previous notebooks has a mechanical cause and represents a physical behavior.
#
# In our [next notebook](11_Equilibrium_Diagram_of_a_Box_Beam_Under_Uniaxial_Compression.ipynb) we will seek further proof of the mechanical nature of the bifurcation break investigating the behaviour of the box beam under a pure compression load applied at the center of the tip section. This type of load is not supposed to break any symmetry and as a consequence we expect to observe the supercritical pitchfork bifurcation to be restored.
